# %%
import http.client 
import pprint
import json

conn = http.client.HTTPSConnection("search.onboard-apis.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "7f4806dadd04980febb182c90a3b8b1c", 
} 

conn.request("GET", "/propertyapi/v1.0.0/property/address?postalcode=08816&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

import ast

pp = pprint.PrettyPrinter(indent=4)
ast.literal_eval(data.decode("utf-8"))
# Out:
# {'property': [{'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '41 SUMMIT DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '41 SUMMIT DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3440',
#     'postal3': 'C029'},
#    'identifier': {'apn': '2100022  0100044',
#     'apnOrig': '21000220100044',
#     'attomId': 28961135,
#     'fips': '34023',
#     'obPropId': 2896113534023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3468790, DB3415210, MT30004131, RS0000296599, SB0000103336, SB0000103338, SB0000103341, SB0000103345, ZI08816',
#     'latitude': '40.390906',
#     'longitude': '-74.441477'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '43 SUMMIT DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '43 SUMMIT DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3440',
#     'postal3': 'C029'},
#    'identifier': {'apn': '2100022  0100045',
#     'apnOrig': '21000220100045',
#     'attomId': 147614953,
#     'fips': '34023',
#     'obPropId': 14761495334023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3468790, DB3415210, MT30004131, RS0000296599, SB0000103336, SB0000103338, SB0000103341, SB0000103345, ZI08816',
#     'latitude': '40.390958',
#     'longitude': '-74.441467'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '45 SUMMIT DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '45 SUMMIT DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3440',
#     'postal3': 'C029'},
#    'identifier': {'apn': '2100022  0100046',
#     'apnOrig': '21000220100046',
#     'attomId': 28961136,
#     'fips': '34023',
#     'obPropId': 2896113634023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3468790, DB3415210, MT30004131, RS0000296599, SB0000103336, SB0000103338, SB0000103341, SB0000103345, ZI08816',
#     'latitude': '40.391011',
#     'longitude': '-74.441457'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '47 SUMMIT DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '47 SUMMIT DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3440',
#     'postal3': 'C029'},
#    'identifier': {'apn': '2100022  0100047',
#     'apnOrig': '21000220100047',
#     'attomId': 140916553,
#     'fips': '34023',
#     'obPropId': 14091655334023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3468790, DB3415210, MT30004131, RS0000296599, SB0000103336, SB0000103338, SB0000103341, SB0000103345, ZI08816',
#     'latitude': '40.391063',
#     'longitude': '-74.441446'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '48 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '48 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000036',
#     'apnOrig': '4003212000036',
#     'attomId': 374693,
#     'fips': '34023',
#     'obPropId': 37469334023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391083',
#     'longitude': '-74.433857'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '50 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '50 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000037',
#     'apnOrig': '4003212000037',
#     'attomId': 190414181,
#     'fips': '34023',
#     'obPropId': 19041418134023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391088',
#     'longitude': '-74.434128'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '46 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '46 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000035',
#     'apnOrig': '4003212000035',
#     'attomId': 200976787,
#     'fips': '34023',
#     'obPropId': 20097678734023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391109',
#     'longitude': '-74.433646'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '49 SUMMIT DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '49 SUMMIT DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3440',
#     'postal3': 'C029'},
#    'identifier': {'apn': '2100022  0100048',
#     'apnOrig': '21000220100048',
#     'attomId': 155538108,
#     'fips': '34023',
#     'obPropId': 15553810834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3468790, DB3415210, MT30004131, RS0000296599, SB0000103336, SB0000103338, SB0000103341, SB0000103345, ZI08816',
#     'latitude': '40.391115',
#     'longitude': '-74.441436'},
#    'vintage': {'lastModified': '2018-5-10', 'pubDate': '2018-5-11'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '52 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '52 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000038',
#     'apnOrig': '4003212000038',
#     'attomId': 15297596,
#     'fips': '34023',
#     'obPropId': 1529759634023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391141',
#     'longitude': '-74.434345'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '42 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '42 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000034',
#     'apnOrig': '4003212000034',
#     'attomId': 188544763,
#     'fips': '34023',
#     'obPropId': 18854476334023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391145',
#     'longitude': '-74.433430'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '51 SUMMIT DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '51 SUMMIT DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3440',
#     'postal3': 'C029'},
#    'identifier': {'apn': '2100022  0100049',
#     'apnOrig': '21000220100049',
#     'attomId': 145229560,
#     'fips': '34023',
#     'obPropId': 14522956034023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3468790, DB3415210, MT30004131, RS0000296599, SB0000103336, SB0000103338, SB0000103341, SB0000103345, ZI08816',
#     'latitude': '40.391167',
#     'longitude': '-74.441426'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '64 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '64 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5287',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100001',
#     'apnOrig': '4003212100001',
#     'attomId': 144038476,
#     'fips': '34023',
#     'obPropId': 14403847634023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391612',
#     'longitude': '-74.435094'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '60 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '60 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000042',
#     'apnOrig': '4003212000042',
#     'attomId': 50319940,
#     'fips': '34023',
#     'obPropId': 5031994034023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391580',
#     'longitude': '-74.435048'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '37 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '37 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5289',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2200009',
#     'apnOrig': '4003212200009',
#     'attomId': 200571212,
#     'fips': '34023',
#     'obPropId': 20057121234023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391512',
#     'longitude': '-74.432977'},
#    'vintage': {'lastModified': '2018-5-10', 'pubDate': '2018-5-11'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '673 OLD STAGE RD',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '673 OLD STAGE RD, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5200',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400573000000002',
#     'apnOrig': '400573000000002',
#     'attomId': 188031691,
#     'fips': '34023',
#     'obPropId': 18803169134023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391471',
#     'longitude': '-74.430655'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '58 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '58 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000041',
#     'apnOrig': '4003212000041',
#     'attomId': 50273330,
#     'fips': '34023',
#     'obPropId': 5027333034023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391466',
#     'longitude': '-74.434896'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '12 AUGUSTA PL',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '12 AUGUSTA PL, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5292',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100025',
#     'apnOrig': '4003212100025',
#     'attomId': 187003081,
#     'fips': '34023',
#     'obPropId': 18700308134023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391464',
#     'longitude': '-74.433704'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '2 MILLER AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '2 MILLER AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5414',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400571000000062',
#     'apnOrig': '400571000000062',
#     'attomId': 21386799,
#     'fips': '34023',
#     'obPropId': 2138679934023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004451914, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08816',
#     'latitude': '40.391448',
#     'longitude': '-74.403165'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '34 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '34 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000030',
#     'apnOrig': '4003212000030',
#     'attomId': 187003079,
#     'fips': '34023',
#     'obPropId': 18700307934023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391446',
#     'longitude': '-74.432539'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '41 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '41 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5289',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2200010',
#     'apnOrig': '4003212200010',
#     'attomId': 198768502,
#     'fips': '34023',
#     'obPropId': 19876850234023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391444',
#     'longitude': '-74.433302'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '47 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '47 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5290',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100019',
#     'apnOrig': '4003212100019',
#     'attomId': 201120388,
#     'fips': '34023',
#     'obPropId': 20112038834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391381',
#     'longitude': '-74.433691'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '51 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '51 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5290',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100017',
#     'apnOrig': '4003212100017',
#     'attomId': 50426403,
#     'fips': '34023',
#     'obPropId': 5042640334023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391356',
#     'longitude': '-74.434053'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '49 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '49 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5290',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100018',
#     'apnOrig': '4003212100018',
#     'attomId': 42673947,
#     'fips': '34023',
#     'obPropId': 4267394734023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391355',
#     'longitude': '-74.433901'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '56 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '56 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000040',
#     'apnOrig': '4003212000040',
#     'attomId': 50238530,
#     'fips': '34023',
#     'obPropId': 5023853034023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391352',
#     'longitude': '-74.434741'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '22 MILLER AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '22 MILLER AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5414',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400571000000085  01',
#     'apnOrig': '40057100000008501',
#     'attomId': 24026568,
#     'fips': '34023',
#     'obPropId': 2402656834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004451914, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08816',
#     'latitude': '40.391348',
#     'longitude': '-74.403425'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '53 SUMMIT DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '53 SUMMIT DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3440',
#     'postal3': 'C029'},
#    'identifier': {'apn': '2100022  0100050',
#     'apnOrig': '21000220100050',
#     'attomId': 151375542,
#     'fips': '34023',
#     'obPropId': 15137554234023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3468790, DB3415210, MT30004131, RS0000296599, SB0000103336, SB0000103338, SB0000103341, SB0000103345, ZI08816',
#     'latitude': '40.391193',
#     'longitude': '-74.441420'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '40 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '40 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000033',
#     'apnOrig': '4003212000033',
#     'attomId': 199607781,
#     'fips': '34023',
#     'obPropId': 19960778134023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391176',
#     'longitude': '-74.433219'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '32 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '32 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000029',
#     'apnOrig': '4003212000029',
#     'attomId': 193191948,
#     'fips': '34023',
#     'obPropId': 19319194834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391652',
#     'longitude': '-74.432397'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '66 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '66 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5287',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100002',
#     'apnOrig': '4003212100002',
#     'attomId': 144038477,
#     'fips': '34023',
#     'obPropId': 14403847734023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391648',
#     'longitude': '-74.435149'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '14 AUGUSTA PL',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '14 AUGUSTA PL, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5292',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100024',
#     'apnOrig': '4003212100024',
#     'attomId': 187003080,
#     'fips': '34023',
#     'obPropId': 18700308034023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391660',
#     'longitude': '-74.433757'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '59 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '59 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5290',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100015',
#     'apnOrig': '4003212100015',
#     'attomId': 50292205,
#     'fips': '34023',
#     'obPropId': 5029220534023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391686',
#     'longitude': '-74.434680'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '57 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '57 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5290',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100016',
#     'apnOrig': '4003212100016',
#     'attomId': 37482262,
#     'fips': '34023',
#     'obPropId': 3748226234023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391573',
#     'longitude': '-74.434529'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '7 MILLER AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '7 MILLER AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5415',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400572000000018',
#     'apnOrig': '400572000000018',
#     'attomId': 21386798,
#     'fips': '34023',
#     'obPropId': 2138679834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004451914, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08816',
#     'latitude': '40.391565',
#     'longitude': '-74.402061'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '11 AUGUSTA PL',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '11 AUGUSTA PL, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5291',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2200015',
#     'apnOrig': '4003212200015',
#     'attomId': 3184726,
#     'fips': '34023',
#     'obPropId': 318472634023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391536',
#     'longitude': '-74.433356'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '9 MILLER AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '9 MILLER AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5415',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400572000000023',
#     'apnOrig': '400572000000023',
#     'attomId': 21386796,
#     'fips': '34023',
#     'obPropId': 2138679634023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004451914, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08816',
#     'latitude': '40.391688',
#     'longitude': '-74.401734'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '68 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '68 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5287',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100003',
#     'apnOrig': '4003212100003',
#     'attomId': 144038478,
#     'fips': '34023',
#     'obPropId': 14403847834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391692',
#     'longitude': '-74.435210'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '3 MILLER AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '3 MILLER AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5415',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400572000000015',
#     'apnOrig': '400572000000015',
#     'attomId': 37862855,
#     'fips': '34023',
#     'obPropId': 3786285534023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004451914, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08816',
#     'latitude': '40.391317',
#     'longitude': '-74.402710'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '36 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '36 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000031',
#     'apnOrig': '4003212000031',
#     'attomId': 50392475,
#     'fips': '34023',
#     'obPropId': 5039247534023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391303',
#     'longitude': '-74.432732'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '54 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '54 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000039',
#     'apnOrig': '4003212000039',
#     'attomId': 50208771,
#     'fips': '34023',
#     'obPropId': 5020877134023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391239',
#     'longitude': '-74.434586'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '38 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '38 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000032',
#     'apnOrig': '4003212000032',
#     'attomId': 42719923,
#     'fips': '34023',
#     'obPropId': 4271992334023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391221',
#     'longitude': '-74.432985'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '67 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '67 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5290',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100011',
#     'apnOrig': '4003212100011',
#     'attomId': 144038473,
#     'fips': '34023',
#     'obPropId': 14403847334023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391877',
#     'longitude': '-74.434949'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '69 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '69 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5290',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100010',
#     'apnOrig': '4003212100010',
#     'attomId': 144038475,
#     'fips': '34023',
#     'obPropId': 14403847534023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391910',
#     'longitude': '-74.434991'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '17 AUGUSTA PL',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '17 AUGUSTA PL, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5291',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2200013',
#     'apnOrig': '4003212200013',
#     'attomId': 197489224,
#     'fips': '34023',
#     'obPropId': 19748922434023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392039',
#     'longitude': '-74.433492'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '6 MILLER AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '6 MILLER AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5414',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400571000000071',
#     'apnOrig': '400571000000071',
#     'attomId': 21386797,
#     'fips': '34023',
#     'obPropId': 2138679734023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004451914, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08816',
#     'latitude': '40.391725',
#     'longitude': '-74.402442'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '70 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '70 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5287',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100004',
#     'apnOrig': '4003212100004',
#     'attomId': 199005909,
#     'fips': '34023',
#     'obPropId': 19900590934023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391732',
#     'longitude': '-74.435261'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '777 HELMETTA BLVD',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '777 HELMETTA BLVD, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3219',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400323000000002  02',
#     'apnOrig': '40032300000000202',
#     'attomId': 188544807,
#     'fips': '34023',
#     'obPropId': 18854480734023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08831',
#     'latitude': '40.391746',
#     'longitude': '-74.436510'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '31 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '31 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5289',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2200008',
#     'apnOrig': '4003212200008',
#     'attomId': 32629712,
#     'fips': '34023',
#     'obPropId': 3262971234023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391757',
#     'longitude': '-74.432727'},
#    'vintage': {'lastModified': '2018-5-10', 'pubDate': '2018-5-11'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '72 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '72 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5287',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100005',
#     'apnOrig': '4003212100005',
#     'attomId': 50235348,
#     'fips': '34023',
#     'obPropId': 5023534834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391771',
#     'longitude': '-74.435312'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '17 MILLER AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '17 MILLER AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5415',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400572000000029  01',
#     'apnOrig': '40057200000002901',
#     'attomId': 21386793,
#     'fips': '34023',
#     'obPropId': 2138679334023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004451914, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08816',
#     'latitude': '40.392182',
#     'longitude': '-74.400428'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '20 PARK KNOLL DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '20 PARK KNOLL DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5281',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  2000003  04',
#     'apnOrig': '400321200000304',
#     'attomId': 188540428,
#     'fips': '34023',
#     'obPropId': 18854042834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392183',
#     'longitude': '-74.431109'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '22 PARK KNOLL DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '22 PARK KNOLL DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5281',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  2000003  05',
#     'apnOrig': '400321200000305',
#     'attomId': 200313566,
#     'fips': '34023',
#     'obPropId': 20031356634023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392206',
#     'longitude': '-74.431418'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '8 PARK KNOLL DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '8 PARK KNOLL DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5280',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  2000002  04',
#     'apnOrig': '400321200000204',
#     'attomId': 37773622,
#     'fips': '34023',
#     'obPropId': 3777362234023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392259',
#     'longitude': '-74.430679'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '71 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '71 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5290',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100009',
#     'apnOrig': '4003212100009',
#     'attomId': 144038479,
#     'fips': '34023',
#     'obPropId': 14403847934023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391949',
#     'longitude': '-74.435042'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '73 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '73 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5290',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100008',
#     'apnOrig': '4003212100008',
#     'attomId': 45336975,
#     'fips': '34023',
#     'obPropId': 4533697534023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.391988',
#     'longitude': '-74.435093'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '10 MILLER AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '10 MILLER AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5414',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400571000000077',
#     'apnOrig': '400571000000077',
#     'attomId': 21386795,
#     'fips': '34023',
#     'obPropId': 2138679534023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004451914, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08816',
#     'latitude': '40.391999',
#     'longitude': '-74.401715'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '75 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '75 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5290',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100007',
#     'apnOrig': '4003212100007',
#     'attomId': 193191949,
#     'fips': '34023',
#     'obPropId': 19319194934023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392027',
#     'longitude': '-74.435143'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '19 AUGUSTA PL',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '19 AUGUSTA PL, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5291',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2200012',
#     'apnOrig': '4003212200012',
#     'attomId': 50262713,
#     'fips': '34023',
#     'obPropId': 5026271334023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392208',
#     'longitude': '-74.433539'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '18 AUGUSTA PL',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '18 AUGUSTA PL, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5292',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2100022',
#     'apnOrig': '4003212100022',
#     'attomId': 201120389,
#     'fips': '34023',
#     'obPropId': 20112038934023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392050',
#     'longitude': '-74.433862'},
# ...
#     'postal1': '08816',
#     'postal2': '5279',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  0900004       C0005',
#     'apnOrig': '04003210900004C0005',
#     'attomId': 201803628,
#     'fips': '34023',
#     'obPropId': 20180362834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392364',
#     'longitude': '-74.430775'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '41 CRESCENT AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '41 CRESCENT AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5410',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400572000000004',
#     'apnOrig': '400572000000004',
#     'attomId': 45735284,
#     'fips': '34023',
#     'obPropId': 4573528434023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004451914, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08816',
#     'latitude': '40.392368',
#     'longitude': '-74.399652'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '6 CRESCENT AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '6 CRESCENT AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5411',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400571000000061',
#     'apnOrig': '400571000000061',
#     'attomId': 193198154,
#     'fips': '34023',
#     'obPropId': 19319815434023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3469810, DB3415540, MT30004131, ND0004451914, PL3469810, SB0000103371, SB0000103372, SB0000103373, SB0000103374, ZI08884',
#     'latitude': '40.392377',
#     'longitude': '-74.398178'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '737 DUNHAMS CORNER RD',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '737 DUNHAMS CORNER RD, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3269',
#     'postal3': 'C029'},
#    'identifier': {'apn': '0400320000000001  04',
#     'apnOrig': '40032000000000104',
#     'attomId': 198768474,
#     'fips': '34023',
#     'obPropId': 19876847434023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3468790, DB3415210, MT30004131, SB0000103336, SB0000103338, SB0000103341, SB0000103345, ZI08816',
#     'latitude': '40.392417',
#     'longitude': '-74.437226'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '30 SUMMIT DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '30 SUMMIT DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3443',
#     'postal3': 'C029'},
#    'identifier': {'apn': '2100022  0200010',
#     'apnOrig': '21000220200010',
#     'attomId': 149586978,
#     'fips': '34023',
#     'obPropId': 14958697834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3468790, DB3415210, MT30004131, RS0000296599, SB0000103336, SB0000103338, SB0000103341, SB0000103345, ZI08816',
#     'latitude': '40.392423',
#     'longitude': '-74.441478'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '94 PENNSBURY WAY # 4',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '94 PENNSBURY WAY # 4, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5279',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  0900004       C0004',
#     'apnOrig': '04003210900004C0004',
#     'attomId': 152997172,
#     'fips': '34023',
#     'obPropId': 15299717234023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392434',
#     'longitude': '-74.430806'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '12 PARK KNOLL DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '12 PARK KNOLL DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5280',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  2000002  06',
#     'apnOrig': '400321200000206',
#     'attomId': 48704599,
#     'fips': '34023',
#     'obPropId': 4870459934023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392240',
#     'longitude': '-74.430754'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '17 PARK KNOLL DR # 1',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '17 PARK KNOLL DR # 1, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5281',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  0900002       C0001',
#     'apnOrig': '04003210900002C0001',
#     'attomId': 144750388,
#     'fips': '34023',
#     'obPropId': 14475038834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392486',
#     'longitude': '-74.430890'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '26 PARK KNOLL DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '26 PARK KNOLL DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5281',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  2000004',
#     'apnOrig': '4003212000004',
#     'attomId': 5247659,
#     'fips': '34023',
#     'obPropId': 524765934023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392503',
#     'longitude': '-74.431913'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '11 PARK KNOLL DR # 6',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '11 PARK KNOLL DR # 6, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5280',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  0900003       C0006',
#     'apnOrig': '04003210900003C0006',
#     'attomId': 199426811,
#     'fips': '34023',
#     'obPropId': 19942681134023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392506',
#     'longitude': '-74.430841'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '92 PENNSBURY WAY # 3',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '92 PENNSBURY WAY # 3, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5279',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  0900004       C0003',
#     'apnOrig': '04003210900004C0003',
#     'attomId': 195299918,
#     'fips': '34023',
#     'obPropId': 19529991834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392506',
#     'longitude': '-74.430837'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '9 PARK KNOLL DR # 5',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '9 PARK KNOLL DR # 5, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5280',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  0900003       C0005',
#     'apnOrig': '04003210900003C0005',
#     'attomId': 32568378,
#     'fips': '34023',
#     'obPropId': 3256837834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392516',
#     'longitude': '-74.430804'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '7 PARK KNOLL DR # 4',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '7 PARK KNOLL DR # 4, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5280',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  0900003       C0004',
#     'apnOrig': '04003210900003C0004',
#     'attomId': 188540416,
#     'fips': '34023',
#     'obPropId': 18854041634023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392525',
#     'longitude': '-74.430766'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '19 MILLER AVE',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '19 MILLER AVE, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5415',
#     'postal3': 'C010'},
#    'identifier': {'apn': '0400572000000035',
#     'apnOrig': '400572000000035',
#     'attomId': 13221490,
#     'fips': '34023',
#     'obPropId': 1322149034023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004451914, SB0000102621, SB0000102622, SB0000136320, SB0000136403, ZI08816',
#     'latitude': '40.392314',
#     'longitude': '-74.400095'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '24 PARK KNOLL DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '24 PARK KNOLL DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5281',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  2000003  06',
#     'apnOrig': '400321200000306',
#     'attomId': 29153159,
#     'fips': '34023',
#     'obPropId': 2915315934023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392318',
#     'longitude': '-74.431698'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '21 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '21 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5289',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2200005',
#     'apnOrig': '4003212200005',
#     'attomId': 203221016,
#     'fips': '34023',
#     'obPropId': 20322101634023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392332',
#     'longitude': '-74.432826'},
#    'vintage': {'lastModified': '2018-8-10', 'pubDate': '2018-8-16'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '21 AUGUSTA PL',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '21 AUGUSTA PL, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5291',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2200011',
#     'apnOrig': '4003212200011',
#     'attomId': 198549764,
#     'fips': '34023',
#     'obPropId': 19854976434023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392362',
#     'longitude': '-74.433574'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '24 BERKSHIRE WAY',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '24 BERKSHIRE WAY, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5286',
#     'postal3': 'C013'},
#    'identifier': {'apn': '0400321  2000025',
#     'apnOrig': '4003212000025',
#     'attomId': 4910198,
#     'fips': '34023',
#     'obPropId': 491019834023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392409',
#     'longitude': '-74.432481'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#   {'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '19 PARK KNOLL DR # 2',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '19 PARK KNOLL DR # 2, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '5281',
#     'postal3': 'C053'},
#    'identifier': {'apn': '0400321  0900002       C0002',
#     'apnOrig': '04003210900002C0002',
#     'attomId': 193174962,
#     'fips': '34023',
#     'obPropId': 19317496234023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3419000, DB3404110, MT30004131, ND0004452968, RS0000375900, SB0000102621, SB0000102622, SB0000136322, SB0000136403, ZI08816',
#     'latitude': '40.392457',
#     'longitude': '-74.431132'},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}}],
#  'status': {'code': 0,
#   'msg': 'SuccessWithResult',
#   'page': 1,
#   'pagesize': 100,
#   'total': 10000,
#   'version': '1.0.0'}}

# %%
# data.decode("utf-8").status

# %%
# conn.request("GET", "/propertyapi/v1.0.0/property/detail?address1=4529%20Winona%20Court&address2=Denver%2C%20CO", headers=headers)

# %%
# url = 'https://www.zipcodestogo.com/New%20Jersey/'

# %%
import pandas as pd

# %%
# len(df)

# %%
zipCs = pd.read_csv('C:/Users/Mike/Downloads/njZips.csv')

# %%
zipCs.dtypes
# Out:
# Zip Code         int64
# City            object
# County          object
# Zip Code Map    object
# dtype: object

# %%
len(zipCs)
# Out:
# 739

# %%
string_codes = []
for row in zipCs["Zip Code"]:
    new = '0' + str(row)
    string_codes.append(new)
zipCs["Zip Code"] = string_codes

# %%
zipCs = zipCs[["Zip Code", "City", "County"]]
zipCs_for_adding = zipCs[["Zip Code", "City", "County"]]

# %%
# zipCs.to_csv('ZIPtoCITYtoCOUNTY.csv', sep=',', encoding='utf-8')

# %%
string_zips = []
for row in zipCs_for_adding["Zip Code"]:
    new = 'zip' + row
#     print(new)
    string_zips.append(new)
zipCs_for_adding["Zip Code"] = string_zips

# %%
# zipCs_for_adding
lists_named = []
for n in zipCs_for_adding["Zip Code"]:
#     globals()[n] = []
    lists_named.append(n)

# %%
lists_named[0:2]
# Out:
# ['zip07001', 'zip07002']

# %%
import http.client 
import pprint
import pymongo
import ast
import time

# %%
### Complete

# counter = 1
# for zipC in zipCs ["Zip Code"]:
    
#     conn = http.client.HTTPSConnection("search.onboard-apis.com") 

#     headers = { 
#         'accept': "application/json", 
#         'apikey': "7f4806dadd04980febb182c90a3b8b1c", 
#     } 


#     conn.request("GET", f"/propertyapi/v1.0.0/property/address?postalcode={zipC}&page=1&pagesize=100", headers=headers) 

#     res = conn.getresponse() 
#     data = res.read() 




#     # Create connection variable
#     conn = 'mongodb://localhost:27017'

#     # Pass connection to the pymongo instance.
#     client = pymongo.MongoClient(conn)

#     # Connect to a database. Will create one if not already available.
#     db = client.House_adds

#     # Drops collection if available to remove duplicates
# #     db.house_locs.drop()

#     # Creates a collection in the database and insert document
#     db.house_locs.insert_one(
#         ast.literal_eval(data.decode("utf-8"))
#     )
#     print(str(counter) + "/739")
#     counter +=1
#     time.sleep(.5)

# %%
conn = http.client.HTTPSConnection("search.onboard-apis.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "7f4806dadd04980febb182c90a3b8b1c", 
} 

conn.request("GET", "/propertyapi/v1.0.0/property/address?postalcode=08816&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

import ast

pp = pprint.PrettyPrinter(indent=4)
zipjson = ast.literal_eval(data.decode("utf-8"))

# %%
for house in zipjson['property']:
    split_add = house['address']['oneLine']
split_add = split_add.split(",")

# %%
# zipjson['property'][0]['address']['oneLine']
# split_add = zipjson['property'][0]['address']['oneLine'].split(",")
# split_add
# Out:
# ['41 SUMMIT DR', ' EAST BRUNSWICK', ' NJ 08816']

# %%
split_add
# Out:
# ['41 SUMMIT DR', ' EAST BRUNSWICK', ' NJ 08816']

# %%
firstPart = split_add[0].replace(" ", "+")
firstPart
# Out:
# '41+SUMMIT+DR'

# %%
secondPart = split_add[1]
secondPart = secondPart[1:]
secondPart = secondPart.replace(" ", "+")
secondPart
# Out:
# 'EAST+BRUNSWICK'

# %%
# zipjson['property'][0]['address']['oneLine'].split(",")
# Out:
# ['41 SUMMIT DR', ' EAST BRUNSWICK', ' NJ 08816']

# %%
conn = http.client.HTTPSConnection("search.onboard-apis.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "7f4806dadd04980febb182c90a3b8b1c", 
} 

url = '/propertyapi/v1.0.0/property/expandedprofile?address1=' + firstPart + "&address2=" + secondPart + "%2C+NJ"
conn.request("GET", url
             , headers=headers) 

res = conn.getresponse() 
data = res.read() 

import ast

pp = pprint.PrettyPrinter(indent=4)
test = ast.literal_eval(data.decode("utf-8"))

# %%
# 607%20Cypress%20Lane&address2=East%20Brunswick%2C%20NJ

# %%
test
# Out:
# {'echoed_fields': {'jobID': '',
#   'loanNumber': '',
#   'preparedBy': '',
#   'preparedFor': '',
#   'resellerID': ''},
#  'property': [{'address': {'country': 'US',
#     'countrySubd': 'NJ',
#     'line1': '41 SUMMIT DR',
#     'line2': 'EAST BRUNSWICK, NJ 08816',
#     'locality': 'East Brunswick',
#     'matchCode': 'ExaStr',
#     'oneLine': '41 SUMMIT DR, EAST BRUNSWICK, NJ 08816',
#     'postal1': '08816',
#     'postal2': '3440',
#     'postal3': 'C029',
#     'stateFips': '34'},
#    'area': {'blockNum': '22.01',
#     'censusBlockGroup': '1',
#     'censusTractIdent': '810402',
#     'countrySecSubd': 'Middlesex County',
#     'countyUse1': '2',
#     'munCode': 'MI',
#     'munName': 'MIDDLESEX',
#     'subdName': 'ESTATES/DURHAM FARM',
#     'subdTractNum': 0,
#     'taxCodeArea': 21},
#    'assessment': {'appraised': {'apprImprValue': 0.0,
#      'apprLandValue': 0.0,
#      'apprTtlValue': 0.0},
#     'assessed': {'assdImprValue': 330000.0,
#      'assdLandValue': 115000.0,
#      'assdTtlValue': 445000.0},
#     'delinquentyear': 0,
#     'fullCashValue': 0,
#     'improvementPercent': 74,
#     'market': {'mktImprValue': 773558.0,
#      'mktLandValue': 269573.0,
#      'mktTtlValue': 1043131.0},
#     'mortgage': {'FirstConcurrent': {'amount': 0.0,
#       'companyCode': '23339',
#       'deedType': 'GD',
#       'interestRate': 0.0},
#      'SecondConcurrent': {'amount': 0.0},
#      'ThirdConcurrent': {'amount': 0.0},
#      'title': {'companyCode': '24', 'companyName': 'FIRST AMERICAN TITLE'}},
#     'owner': {'absenteeOwnerStatus': 'O',
#      'description': 'Individual',
#      'mailingAddressOneLine': '41 SUMMIT DR, EAST BRUNSWICK NJ 088163440',
#      'owner1': {'firstNameAndMi': 'JOHN', 'lastName': 'COLAITUI'},
#      'owner2': {},
#      'type': 'INDIVIDUAL'},
#     'tax': {'exemption': {'ExemptionAmount1': 0.0,
#       'ExemptionAmount2': 0.0,
#       'ExemptionAmount3': 0.0,
#       'ExemptionAmount4': 0.0,
#       'ExemptionAmount5': 0.0},
#      'taxAmt': 22049.75,
#      'taxPerSizeUnit': 4.12,
#      'taxYear': 2017.0}},
#    'building': {'construction': {'frameType': 'TYPE UNKNOWN',
#      'propertyStructureMajorImprovementsYear': '0'},
#     'interior': {'bsmtFinishedPercent': 0, 'bsmtSize': 0, 'fplcCount': 0},
#     'parking': {'prkgSize': 0.0},
#     'rooms': {'bathFixtures': 0,
#      'baths1qtr': 0,
#      'baths3qtr': 0,
#      'bathsCalc': 0.0,
#      'bathsFull': 0,
#      'bathsHalf': 0,
#      'bathsTotal': 0.0,
#      'beds': 0,
#      'roomsTotal': 0},
#     'size': {'atticSize': 0.0,
#      'bldgSize': 0.0,
#      'grossSize': 0.0,
#      'grossSizeAdjusted': 5352.0,
#      'groundFloorSize': 0.0,
#      'livingSize': 5352.0,
#      'sizeInd': 'LIVING SQFT ',
#      'universalSize': 5352.0},
#     'summary': {'levels': 0,
#      'storyDesc': 'TYPE UNKNOWN',
#      'unitsCount': 0,
#      'viewCode': ''}},
#    'identifier': {'apn': '2100022  0100044',
#     'attomId': 28961135,
#     'fips': '34023',
#     'obPropId': 2896113534023},
#    'location': {'accuracy': 'Street',
#     'distance': 0.0,
#     'elevation': 0.0,
#     'geoid': 'CO34023, CS3468790, DB3415210, MT30004131, RS0000296599, SB0000103336, SB0000103338, SB0000103341, SB0000103345, ZI08816',
#     'latitude': '40.390906',
#     'longitude': '-74.441477'},
#    'lot': {'depth': 0.0,
#     'frontage': 0.0,
#     'lotNum': 44,
#     'lotSize1': 2.0,
#     'lotSize2': 87120.0,
#     'siteZoningIdent': 'RR',
#     'zoningType': 'Residential'},
#    'sale': {'amount': {'saleAmt': 1125000.0,
#      'saleDisclosureType': 0,
#      'saleDocNum': '0000000882',
#      'saleRecDate': '2012-1-27',
#      'saleTransType': 'Resale'},
#     'armsLengthIdent': '1',
#     'calculation': {'pricePerBed': 0.0, 'pricePerSizeUnit': 210.0},
#     'recorderThroughDate': '2018-6-27',
#     'saleSearchDate': '2012-1-24',
#     'saleTransDate': '2012-1-24',
#     'sellerName': 'LOISELLE,WALTER A & TINA'},
#    'summary': {'REOflag': '',
#     'absenteeInd': 'OWNER OCCUPIED',
#     'propClass': 'Single Family Residence / Townhouse',
#     'propIndicator': 10,
#     'propLandUse': 'SFR',
#     'propSubType': 'RESIDENTIAL',
#     'propType': 'SFR',
#     'quitClaimFlag': 'False',
#     'yearBuilt': 2008},
#    'utilities': {},
#    'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}}],
#  'status': {'code': 0,
#   'msg': 'SuccessWithResult',
#   'page': 1,
#   'pagesize': 10,
#   'responseDateTime': '2018-10-18T10:35:06',
#   'total': 1,
#   'transactionID': '26e150d1-dd86-4e2a-a48a-547ccf4b26f5',
#   'version': '1.0.0'}}

# %%
zips = pd.read_csv('C:/Users/Mike/Downloads/zips.csv')
list(zips)
# Out:
# ['07001',
#  '07002',
#  '07003',
#  '07004',
#  '07005',
#  '07006',
#  '07008',
#  '07009',
#  '07010',
#  '07012',
#  '07011',
#  '07013',
#  '07014',
#  '07016',
#  '07017',
#  '07018',
#  '07020',
#  '07021',
#  '07022',
#  '07023',
#  '07024',
#  '07026',
#  '07027',
#  '07028',
#  '07029',
#  '07030',
#  '07031',
#  '07032',
#  '07033',
#  '07034',
#  '07035',
#  '07036',
#  '07039',
#  '07040',
#  '07041',
#  '07042',
#  '07043',
#  '07044',
#  '07045',
#  '07046',
#  '07047',
#  '07050',
#  '07052',
#  '07054',
#  '07055',
#  '07057',
#  '07058',
#  '07059',
#  '07060',
#  '07062',
#  '07063',
#  '07064',
#  '07066',
#  '07065',
#  '07067',
#  '07068',
#  '07069',
#  '07070',
#  '07071',
#  '07072',
#  '07073',
#  '07074',
#  '07075',
#  '07076',
#  '07077',
#  '07078',
#  '07079',
#  '07080',
#  '07081',
#  '07082',
#  '07083',
#  '07086',
#  '07087',
#  '07088',
#  '07090',
#  '07092',
#  '07093',
#  '07094',
#  '07095',
#  '07102',
#  '07103',
#  '07104',
#  '07105',
#  '07106',
#  '07107',
#  '07108',
#  '07109',
#  '07110',
#  '07111',
#  '07112',
#  '07114',
#  '07201',
#  '07202',
#  '07203',
#  '07204',
#  '07205',
#  '07206',
#  '07208',
#  '07302',
#  '07304',
#  '07305',
#  '07306',
#  '07307',
#  '07310',
#  '07311',
#  '07401',
#  '07403',
#  '07405',
#  '07407',
#  '07410',
#  '07416',
#  '07417',
#  '07418',
#  '07419',
#  '07420',
#  '07421',
#  '07422',
#  '07423',
#  '07424',
#  '07430',
#  '07432',
#  '07435',
#  '07436',
#  '07438',
#  '07439',
#  '07440',
#  '07442',
#  '07444',
#  '07446',
#  '07450',
#  '07452',
#  '07456',
#  '07457',
#  '07458',
#  '07460',
#  '07461',
#  '07462',
#  '07463',
#  '07465',
#  '07470',
#  '07480',
#  '07481',
#  '07501',
#  '07502',
#  '07503',
#  '07504',
#  '07505',
#  '07506',
#  '07508',
#  '07512',
#  '07513',
#  '07514',
#  '07522',
#  '07524',
#  '07601',
#  '07603',
#  '07604',
#  '07605',
#  '07606',
#  '07607',
#  '07608',
#  '07620',
#  '07621',
#  '07624',
#  '07626',
#  '07627',
#  '07628',
#  '07630',
#  '07631',
#  '07632',
#  '07640',
#  '07641',
#  '07642',
#  '07643',
#  '07644',
#  '07645',
#  '07646',
#  '07647',
#  '07648',
#  '07649',
#  '07650',
#  '07652',
#  '07656',
#  '07657',
#  '07660',
#  '07661',
#  '07662',
#  '07663',
#  '07666',
#  '07670',
#  '07675',
#  '07676',
#  '07677',
#  '07701',
#  '07702',
#  '07703',
#  '07704',
#  '07711',
#  '07712',
#  '07716',
#  '07717',
#  '07718',
#  '07719',
#  '07720',
#  '07721',
#  '07722',
#  '07723',
#  '07724',
#  '07726',
#  '07727',
#  '07728',
#  '07730',
#  '07731',
#  '07732',
#  '07733',
#  '07734',
#  '07735',
#  '07737',
#  '07738',
#  '07739',
#  '07740',
#  '07746',
#  '07747',
#  '07748',
#  '07750',
#  '07751',
#  '07753',
#  '07755',
#  '07756',
#  '07757',
#  '07758',
#  '07760',
#  '07762',
#  '07764',
#  '07801',
#  '07803',
#  '07820',
#  '07821',
#  '07822',
#  '07823',
#  '07825',
#  '07826',
#  '07827',
#  '07828',
#  '07830',
#  '07832',
#  '07833',
#  '07834',
#  '07836',
#  '07838',
#  '07840',
#  '07842',
#  '07843',
#  '07846',
#  '07847',
#  '07848',
#  '07849',
#  '07850',
#  '07851',
#  '07852',
#  '07853',
#  '07856',
#  '07857',
#  '07860',
#  '07863',
#  '07865',
#  '07866',
#  '07869',
#  '07870',
#  '07871',
#  '07874',
#  '07876',
#  '07878',
#  '07880',
#  '07881',
#  '07882',
#  '07885',
#  '07901',
#  '07920',
#  '07921',
#  '07922',
#  '07924',
#  '07926',
#  '07927',
#  '07928',
#  '07930',
#  '07931',
#  '07932',
#  '07933',
#  '07934',
#  '07935',
#  '07936',
#  '07939',
#  '07940',
#  '07945',
#  '07946',
#  '07950',
#  '07950.1',
#  '07960',
#  '07961',
#  '07970',
#  '07974',
#  '07976',
#  '07977',
#  '07979',
#  '07980',
#  '07981',
#  '08001',
#  '08002',
#  '08003',
#  '08004',
#  '08005',
#  '08006',
#  '08007',
#  '08008',
#  '08009',
#  '08010',
#  '08011',
#  '08012',
#  '08014',
#  '08015',
#  '08016',
#  '08019',
#  '08020',
#  '08021',
#  '08022',
#  '08023',
#  '08026',
#  '08027',
#  '08028',
#  '08029',
#  '08030',
#  '08031',
#  '08033',
#  '08034',
#  '08035',
#  '08036',
#  '08037',
#  '08038',
#  '08039',
#  '08041',
#  '08042',
#  '08043',
#  '08045',
#  '08046',
#  '08048',
#  '08049',
#  '08050',
#  '08051',
#  '08052',
#  '08053',
#  '08054',
#  '08055',
#  '08056',
#  '08057',
#  '08059',
#  '08060',
#  '08061',
#  '08062',
#  '08063',
#  '08064',
#  '08065',
#  '08066',
#  '08067',
#  '08068',
#  '08069',
#  '08070',
#  '08071',
#  '08072',
#  '08073',
#  '08074',
#  '08075',
#  '08077',
#  '08078',
#  '08079',
#  '08080',
#  '08081',
#  '08083',
#  '08084',
#  '08085',
#  '08086',
#  '08087',
#  '08088',
#  '08089',
#  '08090',
#  '08091',
#  '08092',
#  '08093',
#  '08094',
#  '08095',
#  '08096',
#  '08096.1',
#  '08097',
#  '08098',
#  '08102',
#  '08103',
#  '08104',
#  '08104.1',
#  '08105',
#  '08106',
#  '08107',
#  '08107.1',
#  '08108',
#  '08108.1',
#  '08109',
#  '08110',
#  '08201',
#  '08202',
#  '08203',
#  '08204',
#  '08205',
#  '08210',
#  '08212',
#  '08215',
#  '08217',
#  '08221',
#  '08223',
#  '08224',
#  '08225',
#  '08226',
#  '08230',
#  '08232',
#  '08234',
#  '08240',
#  '08241',
#  '08242',
#  '08243',
#  '08244',
#  '08246',
#  '08247',
#  '08248',
#  '08251',
#  '08260',
#  '08270',
#  '08302',
#  '08310',
#  '08311',
#  '08312',
#  '08314',
#  '08316',
#  '08317',
#  '08318',
#  '08319',
#  '08320',
#  '08321',
#  '08322',
#  '08323',
#  '08324',
#  '08326',
#  '08327',
#  '08328',
#  '08329',
#  '08330',
#  '08332',
#  '08340',
#  '08341',
#  '08343',
#  '08344',
#  '08345',
#  '08346',
#  '08348',
#  '08349',
#  '08350',
#  '08352',
#  '08353',
#  '08360',
#  '08361',
#  '08401',
#  '08402',
#  '08403',
#  '08406',
#  '08501',
#  '08502',
#  '08505',
#  '08510',
#  '08511',
#  '08512',
#  '08514',
#  '08515',
#  '08518',
#  '08520',
#  '08525',
#  '08527',
#  '08528',
#  '08530',
#  '08533',
#  '08534',
#  '08535',
#  '08536',
#  '08540',
#  '08542',
#  '08550',
#  '08551',
#  '08553',
#  '08554',
#  '08555',
#  '08558',
#  '08559',
#  '08560',
#  '08561',
#  '08562',
#  '08608',
#  '08609',
#  '08610',
#  '08611',
#  '08618',
#  '08619',
#  '08620',
#  '08628',
#  '08629',
#  '08638',
#  '08640',
#  '08641',
#  '08648',
#  '08690',
#  '08691',
#  '08701',
#  '08720',
#  '08721',
#  '08722',
#  '08723',
#  '08724',
#  '08730',
#  '08731',
#  '08732',
#  '08733',
#  '08734',
#  '08735',
#  '08736',
#  '08738',
#  '08740',
#  '08741',
#  '08742',
#  '08750',
#  '08751',
#  '08752',
#  '08753',
#  '08755',
#  '08757',
#  '08758',
#  '08759',
#  '08801',
#  '08802',
#  '08804',
#  '08805',
#  '08807',
#  '08808',
#  '08809',
#  '08810',
#  '08812',
#  '08816',
#  '08817',
#  '08820',
#  '08821',
#  '08822',
#  '08823',
#  '08824',
#  '08825',
#  '08826',
#  '08827',
#  '08828',
#  '08829',
#  '08830',
#  '08831',
#  '08832',
#  '08833',
#  '08835',
#  '08836',
#  '08837',
#  '08840',
#  '08844',
#  '08846',
#  '08848',
#  '08850',
#  '08852',
#  '08853',
#  '08854',
#  '08857',
#  '08858',
#  '08859',
#  '08861',
#  '08863',
#  '08865',
#  '08867',
#  '08869',
#  '08872',
#  '08873',
#  '08876',
#  '08879',
#  '08880',
#  '08882',
#  '08884',
#  '08886',
#  '08887',
#  '08889',
#  '08890',
#  '08901',
#  '08902',
#  '08904']

# %%
#Final Workings
import http.client 
import pprint
import json
import pandas as pd
import time
import pymongo
from pymongo import MongoClient

zipCs = pd.read_csv('C:/Users/Mike/Downloads/zips.csv')
# string_codes = []
# for row in zipCs["Zip Code"]:
#     new = '0' + str(row)
#     string_codes.append(new)
# zipCs["Zip Code"] = string_codes   

# zipCs = zipCs[["Zip Code", "City", "County"]]

for zipC in zipCs:

    
    conn = http.client.HTTPSConnection("search.onboard-apis.com") 

    headers = { 
        'accept': "application/json", 
        'apikey': "19b9df458131fa92b0779217d59cf34c", 
    } 


    conn.request("GET", f"/propertyapi/v1.0.0/property/address?postalcode={zipC}&page=1&pagesize=100", headers=headers) 

    res = conn.getresponse() 
    data = res.read() 
    import ast
    zipjson = ast.literal_eval(data.decode("utf-8"))
    from pprint import pprint
    pprint(zipjson['property'])
#     break
    
    for house in zipjson['property']:
#         print(house)
        
        split_add = house['address']['oneLine']
        split_add = split_add.split(",")
        
    
        firstPart = split_add[0].replace(" ", "+")
#         print(firstPart)

        secondPart = split_add[1]
        secondPart = secondPart[1:]
        secondPart = secondPart.replace(" ", "+")
#         print(secondPart)

        conn = http.client.HTTPSConnection("search.onboard-apis.com") 
    
        headers = { 
        'accept': "application/json", 
        'apikey': "19b9df458131fa92b0779217d59cf34c", 
        } 

        url2 = "/propertyapi/v1.0.0/property/expandedprofile?address1=" + firstPart + "&address2=" + secondPart + "%2C+NJ"
#         print(url2)
        conn.request("GET", url2, headers=headers) 

        restH = conn.getresponse() 
#         print(restH)
        dataH = restH.read()
#         print(dataH)
#         import ast
        house_props = ast.literal_eval(dataH.decode("utf-8"))
#         pp = pprint.PrettyPrinter(indent=4)
#         pp.pprint(house_props)
#         print(type(house_props))
#         break
    
    #Create connection variable
        conn = MongoClient('mongodb://mike:mikepassword1@ds137003.mlab.com:37003/project3')

        # Pass connection to the pymongo instance.
#         client = pymongo.MongoClient(conn)

        # Connect to a database. Will create one if not already available.
        db = conn.get_database()

        # Drops collection if available to remove duplicates
#         db.house_locs.drop()

        # Creates a collection in the database and insert document
        
        db.house_details2.insert_one(
            house_props
        )
#         time.sleep(.15)
#         break
# Out:
# [{'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '191 BLAIR RD',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '191 BLAIR RD, AVENEL, NJ 07001',
#               'postal1': '07001'},
#   'identifier': {'apn': '2500974000000012  01',
#                  'apnOrig': '250097400000001201',
#                  'attomId': 189917286,
#                  'fips': '34023',
#                  'obPropId': 18991728634023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, SB0000103533, SB0000103542, '
#                         'SB0000103554, ZI07001',
#                'latitude': '40.570563',
#                'longitude': '-74.259186'},
#   'vintage': {'lastModified': '2018-5-10', 'pubDate': '2018-5-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '412 ROANOKE ST',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '412 ROANOKE ST, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1317',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848 02100016',
#                  'apnOrig': '250084802100016',
#                  'attomId': 13891534,
#                  'fips': '34023',
#                  'obPropId': 1389153434023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712692, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.570787',
#                'longitude': '-74.288711'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '414 ROANOKE ST',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '414 ROANOKE ST, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1317',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848 02100015',
#                  'apnOrig': '250084802100015',
#                  'attomId': 187196342,
#                  'fips': '34023',
#                  'obPropId': 18719634234023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712692, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.570838',
#                'longitude': '-74.288661'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '416 ROANOKE ST',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '416 ROANOKE ST, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1317',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848 02100014',
#                  'apnOrig': '250084802100014',
#                  'attomId': 188872526,
#                  'fips': '34023',
#                  'obPropId': 18887252634023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712692, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.570888',
#                'longitude': '-74.288611'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '413 ROANOKE ST',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '413 ROANOKE ST, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1326',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848 02600012',
#                  'apnOrig': '250084802600012',
#                  'attomId': 203270668,
#                  'fips': '34023',
#                  'obPropId': 20327066834023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712692, SB0000103531, '
#                         'SB0000103538, SB0000103554, ZI07095',
#                'latitude': '40.570980',
#                'longitude': '-74.288968'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1005 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1005 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1378',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1005',
#                  'apnOrig': '2500848000000010C1005',
#                  'attomId': 189754945,
#                  'fips': '34023',
#                  'obPropId': 18975494534023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07095',
#                'latitude': '40.571788',
#                'longitude': '-74.284627'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1003 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1003 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1378',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1003',
#                  'apnOrig': '2500848000000010C1003',
#                  'attomId': 190808843,
#                  'fips': '34023',
#                  'obPropId': 19080884334023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07095',
#                'latitude': '40.571789',
#                'longitude': '-74.284624'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1001 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1001 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1378',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1001',
#                  'apnOrig': '2500848000000010C1001',
#                  'attomId': 50241419,
#                  'fips': '34023',
#                  'obPropId': 5024141934023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07095',
#                'latitude': '40.571790',
#                'longitude': '-74.284620'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '905 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '905 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1364',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0905',
#                  'apnOrig': '2500848000000010C0905',
#                  'attomId': 193920110,
#                  'fips': '34023',
#                  'obPropId': 19392011034023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07095',
#                'latitude': '40.571848',
#                'longitude': '-74.284454'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '903 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '903 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1364',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0903',
#                  'apnOrig': '2500848000000010C0903',
#                  'attomId': 52262818,
#                  'fips': '34023',
#                  'obPropId': 5226281834023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07095',
#                'latitude': '40.571850',
#                'longitude': '-74.284451'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '901 MADALINE DR # 901',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '901 MADALINE DR # 901, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1364',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0901',
#                  'apnOrig': '2500848000000010C0901',
#                  'attomId': 50072067,
#                  'fips': '34023',
#                  'obPropId': 5007206734023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07095',
#                'latitude': '40.571851',
#                'longitude': '-74.284447'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '805 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '805 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1363',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0805',
#                  'apnOrig': '2500848000000010C0805',
#                  'attomId': 200723518,
#                  'fips': '34023',
#                  'obPropId': 20072351834023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07095',
#                'latitude': '40.571909',
#                'longitude': '-74.284281'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '803 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '803 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1363',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0803',
#                  'apnOrig': '2500848000000010C0803',
#                  'attomId': 32472273,
#                  'fips': '34023',
#                  'obPropId': 3247227334023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07095',
#                'latitude': '40.571910',
#                'longitude': '-74.284277'},
#   'vintage': {'lastModified': '2018-5-10', 'pubDate': '2018-5-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '801 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '801 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1363',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0801',
#                  'apnOrig': '2500848000000010C0801',
#                  'attomId': 198769375,
#                  'fips': '34023',
#                  'obPropId': 19876937534023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07095',
#                'latitude': '40.571911',
#                'longitude': '-74.284274'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '703 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '703 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1361',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0703',
#                  'apnOrig': '2500848000000010C0703',
#                  'attomId': 38627336,
#                  'fips': '34023',
#                  'obPropId': 3862733634023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.571971',
#                'longitude': '-74.284104'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '701 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '701 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1361',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0701',
#                  'apnOrig': '2500848000000010C0701',
#                  'attomId': 195605209,
#                  'fips': '34023',
#                  'obPropId': 19560520934023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.571972',
#                'longitude': '-74.284100'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '603 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '603 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1360',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0603',
#                  'apnOrig': '2500848000000010C0603',
#                  'attomId': 39620263,
#                  'fips': '34023',
#                  'obPropId': 3962026334023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572027',
#                'longitude': '-74.283938'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '601 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '601 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1360',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0601',
#                  'apnOrig': '2500848000000010C0601',
#                  'attomId': 39620258,
#                  'fips': '34023',
#                  'obPropId': 3962025834023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572028',
#                'longitude': '-74.283934'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1006 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1006 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1378',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1006',
#                  'apnOrig': '2500848000000010C1006',
#                  'attomId': 32700211,
#                  'fips': '34023',
#                  'obPropId': 3270021134023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572045',
#                'longitude': '-74.284750'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1004 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1004 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1378',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1004',
#                  'apnOrig': '2500848000000010C1004',
#                  'attomId': 48484089,
#                  'fips': '34023',
#                  'obPropId': 4848408934023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572046',
#                'longitude': '-74.284747'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1002 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1002 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1378',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1002',
#                  'apnOrig': '2500848000000010C1002',
#                  'attomId': 199968560,
#                  'fips': '34023',
#                  'obPropId': 19996856034023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572048',
#                'longitude': '-74.284743'},
#   'vintage': {'lastModified': '2018-8-10', 'pubDate': '2018-8-16'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '505 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '505 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1351',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0505',
#                  'apnOrig': '2500848000000010C0505',
#                  'attomId': 37917911,
#                  'fips': '34023',
#                  'obPropId': 3791791134023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572065',
#                'longitude': '-74.283783'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '503 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '503 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1351',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0503',
#                  'apnOrig': '2500848000000010C0503',
#                  'attomId': 32492306,
#                  'fips': '34023',
#                  'obPropId': 3249230634023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572066',
#                'longitude': '-74.283779'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '501 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '501 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1351',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0501',
#                  'apnOrig': '2500848000000010C0501',
#                  'attomId': 39620227,
#                  'fips': '34023',
#                  'obPropId': 3962022734023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0002712695, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572066',
#                'longitude': '-74.283776'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '405 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '405 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1359',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0405',
#                  'apnOrig': '2500848000000010C0405',
#                  'attomId': 3030272,
#                  'fips': '34023',
#                  'obPropId': 303027234023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572083',
#                'longitude': '-74.283622'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '403 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '403 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1359',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0403',
#                  'apnOrig': '2500848000000010C0403',
#                  'attomId': 39620204,
#                  'fips': '34023',
#                  'obPropId': 3962020434023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572083',
#                'longitude': '-74.283618'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '401 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '401 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1359',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0401',
#                  'apnOrig': '2500848000000010C0401',
#                  'attomId': 39620198,
#                  'fips': '34023',
#                  'obPropId': 3962019834023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572083',
#                'longitude': '-74.283614'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '305 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '305 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1358',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0305',
#                  'apnOrig': '2500848000000010C0305',
#                  'attomId': 39620192,
#                  'fips': '34023',
#                  'obPropId': 3962019234023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572084',
#                'longitude': '-74.283416'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '303 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '303 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1358',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0303',
#                  'apnOrig': '2500848000000010C0303',
#                  'attomId': 32984109,
#                  'fips': '34023',
#                  'obPropId': 3298410934023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572084',
#                'longitude': '-74.283412'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '301 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '301 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1358',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0301',
#                  'apnOrig': '2500848000000010C0301',
#                  'attomId': 48677617,
#                  'fips': '34023',
#                  'obPropId': 4867761734023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572085',
#                'longitude': '-74.283408'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '906 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '906 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1364',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0906',
#                  'apnOrig': '2500848000000010C0906',
#                  'attomId': 189754944,
#                  'fips': '34023',
#                  'obPropId': 18975494434023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572106',
#                'longitude': '-74.284577'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '904 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '904 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1364',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0904',
#                  'apnOrig': '2500848000000010C0904',
#                  'attomId': 195163303,
#                  'fips': '34023',
#                  'obPropId': 19516330334023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572107',
#                'longitude': '-74.284573'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '902 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '902 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1364',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0902',
#                  'apnOrig': '2500848000000010C0902',
#                  'attomId': 48657753,
#                  'fips': '34023',
#                  'obPropId': 4865775334023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572108',
#                'longitude': '-74.284570'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '205 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '205 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1300',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0205',
#                  'apnOrig': '2500848000000010C0205',
#                  'attomId': 42477963,
#                  'fips': '34023',
#                  'obPropId': 4247796334023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572109',
#                'longitude': '-74.283210'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '203 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '203 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1300',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0203',
#                  'apnOrig': '2500848000000010C0203',
#                  'attomId': 48571941,
#                  'fips': '34023',
#                  'obPropId': 4857194134023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572110',
#                'longitude': '-74.283206'},
#   'vintage': {'lastModified': '2018-8-10', 'pubDate': '2018-8-16'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '201 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '201 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1300',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0201',
#                  'apnOrig': '2500848000000010C0201',
#                  'attomId': 32444399,
#                  'fips': '34023',
#                  'obPropId': 3244439934023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572111',
#                'longitude': '-74.283203'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1101 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1101 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1379',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1101',
#                  'apnOrig': '2500848000000010C1101',
#                  'attomId': 48640247,
#                  'fips': '34023',
#                  'obPropId': 4864024734023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572145',
#                'longitude': '-74.283018'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '101 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '101 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1348',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0101',
#                  'apnOrig': '2500848000000010C0101',
#                  'attomId': 45310464,
#                  'fips': '34023',
#                  'obPropId': 4531046434023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572145',
#                'longitude': '-74.283017'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1103 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1103 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1379',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1103',
#                  'apnOrig': '2500848000000010C1103',
#                  'attomId': 189754946,
#                  'fips': '34023',
#                  'obPropId': 18975494634023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572146',
#                'longitude': '-74.283014'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1105 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1105 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1379',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1105',
#                  'apnOrig': '2500848000000010C1105',
#                  'attomId': 186670618,
#                  'fips': '34023',
#                  'obPropId': 18667061834023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572146',
#                'longitude': '-74.283011'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '806 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '806 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1363',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0806',
#                  'apnOrig': '2500848000000010C0806',
#                  'attomId': 32472935,
#                  'fips': '34023',
#                  'obPropId': 3247293534023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572167',
#                'longitude': '-74.284403'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '804 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '804 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1363',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0804',
#                  'apnOrig': '2500848000000010C0804',
#                  'attomId': 32472513,
#                  'fips': '34023',
#                  'obPropId': 3247251334023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572168',
#                'longitude': '-74.284400'},
#   'vintage': {'lastModified': '2018-5-10', 'pubDate': '2018-5-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '802 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '802 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1363',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C0802',
#                  'apnOrig': '2500848000000010C0802',
#                  'attomId': 193920109,
#                  'fips': '34023',
#                  'obPropId': 19392010934023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572169',
#                'longitude': '-74.284396'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '878 RAHWAY AVE',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '878 RAHWAY AVE, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1949',
#               'postal3': 'C004'},
#   'identifier': {'apn': '2501007000000082',
#                  'apnOrig': '2501007000000082',
#                  'attomId': 4289516,
#                  'fips': '34023',
#                  'obPropId': 428951634023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, SB0000103531, SB0000103538, '
#                         'SB0000103554, ZI07001',
#                'latitude': '40.572173',
#                'longitude': '-74.270831'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1201 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1201 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1380',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1201',
#                  'apnOrig': '2500848000000010C1201',
#                  'attomId': 186670619,
#                  'fips': '34023',
#                  'obPropId': 18667061934023},
# ...
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1102 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1102 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1379',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1102',
#                  'apnOrig': '2500848000000010C1102',
#                  'attomId': 195163304,
#                  'fips': '34023',
#                  'obPropId': 19516330434023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572416',
#                'longitude': '-74.283078'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1104 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1104 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1379',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1104',
#                  'apnOrig': '2500848000000010C1104',
#                  'attomId': 37756927,
#                  'fips': '34023',
#                  'obPropId': 3775692734023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572416',
#                'longitude': '-74.283075'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1106 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1106 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1379',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1106',
#                  'apnOrig': '2500848000000010C1106',
#                  'attomId': 37757351,
#                  'fips': '34023',
#                  'obPropId': 3775735134023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572417',
#                'longitude': '-74.283071'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '2001 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '2001 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1377',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C2001',
#                  'apnOrig': '2500848000000010C2001',
#                  'attomId': 37723239,
#                  'fips': '34023',
#                  'obPropId': 3772323934023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572444',
#                'longitude': '-74.281357'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '2003 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '2003 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1377',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C2003',
#                  'apnOrig': '2500848000000010C2003',
#                  'attomId': 32436358,
#                  'fips': '34023',
#                  'obPropId': 3243635834023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572445',
#                'longitude': '-74.281354'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '17 BERKSHIRE ST',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '17 BERKSHIRE ST, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1309',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500847  1000022  02',
#                  'apnOrig': '2500847100002202',
#                  'attomId': 144166029,
#                  'fips': '34023',
#                  'obPropId': 14416602934023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, SB0000103531, SB0000103538, '
#                         'SB0000103554, ZI07095',
#                'latitude': '40.572448',
#                'longitude': '-74.289653'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '1202 MADALINE DR',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '1202 MADALINE DR, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1380',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500848000000010       C1202',
#                  'apnOrig': '2500848000000010C1202',
#                  'attomId': 199968561,
#                  'fips': '34023',
#                  'obPropId': 19996856134023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, RS0000316215, SB0000103531, '
#                         'SB0000103537, SB0000103538, ZI07001',
#                'latitude': '40.572449',
#                'longitude': '-74.282894'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '15 BERKSHIRE ST',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '15 BERKSHIRE ST, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1309',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500847  1000028',
#                  'apnOrig': '25008471000028',
#                  'attomId': 48639427,
#                  'fips': '34023',
#                  'obPropId': 4863942734023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, SB0000103531, SB0000103538, '
#                         'SB0000103554, ZI07095',
#                'latitude': '40.572452',
#                'longitude': '-74.289857'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'NJ',
#               'line1': '30 BERKSHIRE ST',
#               'line2': 'AVENEL, NJ 07001',
#               'locality': 'Avenel',
#               'matchCode': 'ExaStr',
#               'oneLine': '30 BERKSHIRE ST, AVENEL, NJ 07001',
#               'postal1': '07001',
#               'postal2': '1309',
#               'postal3': 'C006'},
#   'identifier': {'apn': '2500847  1300018',
#                  'apnOrig': '25008471300018',
#                  'attomId': 25533672,
#                  'fips': '34023',
#                  'obPropId': 2553367234023},
#   'location': {'accuracy': 'Street',
#                'distance': 0.0,
#                'elevation': 0.0,
#                'geoid': 'CO34023, CS3482000, DB3418120, MT30004143, '
#                         'ND0001569963, PL3402350, SB0000103531, SB0000103538, '
#                         'SB0000103554, ZI07095',
#                'latitude': '40.572458',
#                'longitude': '-74.288635'},
#   'vintage': {'lastModified': '2018-6-11', 'pubDate': '2018-6-12'}}]
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-10-2d408061b122> in <module>()
#      90
#      91         db.house_details2.insert_one(
# ---> 92             house_props
#      93         )
#      94 #         time.sleep(.15)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     691                          write_concern=write_concern,
#     692                          bypass_doc_val=bypass_document_validation,
# --> 693                          session=session),
#     694             write_concern.acknowledged)
#     695
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     605             return self._insert_one(
#     606                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 607                 bypass_doc_val, session)
#     608
#     609         ids = []
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     593
#     594         self.__database.client._retryable_write(
# --> 595             acknowledged, _insert_command, session)
#     596
#     597         if not isinstance(doc, RawBSONDocument):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1241         """Internal retryable write helper."""
#    1242         with self._tmp_session(session) as s:
# -> 1243             return self._retry_with_session(retryable, func, s, None)
#    1244
#    1245     def __reset_server(self, address):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1184                     session is not None and
#    1185                     server.description.retryable_writes_supported)
# -> 1186                 with self._get_socket(server) as sock_info:
#    1187                     if retryable and not supports_session:
#    1188                         if is_retrying():
#
# ~\Anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in _get_socket(self, server)
#    1056     def _get_socket(self, server):
#    1057         try:
# -> 1058             with server.get_socket(self.__all_credentials) as sock_info:
#    1059                 yield sock_info
#    1060         except NetworkTimeout:
#
# ~\Anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\pool.py in get_socket(self, all_credentials, checkout)
#    1004         sock_info = self._get_socket_no_auth()
#    1005         try:
# -> 1006             sock_info.check_auth(all_credentials)
#    1007             yield sock_info
#    1008         except:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\pool.py in check_auth(self, all_credentials)
#     675
#     676             for credentials in cached - authset:
# --> 677                 auth.authenticate(credentials, self)
#     678                 self.authset.add(credentials)
#     679
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\auth.py in authenticate(credentials, sock_info)
#     561     mechanism = credentials.mechanism
#     562     auth_func = _AUTH_MAP.get(mechanism)
# --> 563     auth_func(credentials, sock_info)
#     564
#     565
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\auth.py in _authenticate_default(credentials, sock_info)
#     538             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     539     elif sock_info.max_wire_version >= 3:
# --> 540         return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     541     else:
#     542         return _authenticate_mongo_cr(credentials, sock_info)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     298                ('conversationId', res['conversationId']),
#     299                ('payload', Binary(client_final))])
# --> 300     res = sock_info.command(source, cmd)
#     301
#     302     parsed = _parse_scram_response(res['payload'])
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     577                            compression_ctx=self.compression_context,
#     578                            use_op_msg=self.op_msg_enabled,
# --> 579                            unacknowledged=unacknowledged)
#     580         except OperationFailure:
#     581             raise
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged)
#     148                 helpers._check_command_response(
#     149                     response_doc, None, allowable_errors,
# --> 150                     parse_write_concern_error=parse_write_concern_error)
#     151     except Exception as exc:
#     152         if publish:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\helpers.py in _check_command_response(response, msg, allowable_errors, parse_write_concern_error)
#     153
#     154             msg = msg or "%s"
# --> 155             raise OperationFailure(msg % errmsg, code, response)
#     156
#     157
#
# OperationFailure: Authentication failed.
